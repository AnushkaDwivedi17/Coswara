# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/anushkadwivedi'

# %%
path = os.getcwd()
file = 'Python_work'
new_path = os.path.join(path,file)
os.chdir(new_path)

# %%
os.getcwd()
# Out:
# '/Users/anushkadwivedi/Python_work'

# %%
path = os.getcwd()
file = 'Coswara-Data'
new_path = os.path.join(path,file)
os.chdir(new_path)

# %%
os.listdir()
# Out:
# ['Extracted_data',
#  '20200413',
#  '20200820',
#  'LICENSE.md',
#  '20200415',
#  '20200424',
#  '20210618',
#  '20200502',
#  '.DS_Store',
#  '20200505',
#  '20201221',
#  '20200504',
#  '20200707',
#  '20200901',
#  '20200930',
#  '20201012',
#  '20201031',
#  '20200803',
#  '20210406',
#  '20200430',
#  '20210603',
#  '20200604',
#  'README.md',
#  '20200824',
#  '20210426',
#  '20201130',
#  '20210419',
#  '20200419',
#  '20200417',
#  '20200814',
#  '20200416',
#  '.gitignore',
#  '20200418',
#  '20210507',
#  'combined_data.csv',
#  '20200525',
#  '20200911',
#  'extract_data.py',
#  '.git',
#  '20200720',
#  'csv_labels_legend.json',
#  '20200919',
#  '20210523',
#  '20210630',
#  '20210206']

# %%
import pandas as pd

# %%
import numpy as np

# %%
import librosa

# %%
os.getcwd()
# Out:
# '/Users/anushkadwivedi/Python_work/Coswara-Data'

# %%
path = os.getcwd()
file = 'Extracted_data/20200413'
new_path = os.path.join(path,file)
os.chdir(new_path)

# %%
os.listdir()
# Out:
# ['vK2bLRNzllXNeyOMudnNSL5cfpG2',
#  'bjA2KpSxneNskrLBeqi4bqoTDQl2',
#  'FSzobvJqOXf0rI6X05cHqOiU9Mu2',
#  'EqDWckxbsETyHUeBLQ8jLtxlhir2',
#  'FGRDO4IBbAejR0WHD5YbkXTCasg2',
#  'htQzROl26OWQpIYFDzv11F79PLR2',
#  'pW9mCAeWYiMoM7wW7riLvNRbYDO2',
#  'Eu11s84cuBTiPXTAtVf9mj3GkqA2',
#  'L7S8iIPKgiO6QWLC3mGkROCMa0s1',
#  'eP8gEM0KcBU6S5JpMdycX74KP3p2',
#  'UiUUhL0PMjWVA6W2dKte1DCE6wG2',
#  '2TkAK2YVkYS7Ux3hAPBUgYgg9DI3',
#  'QQbzKidDxHQ0eZFEL4uG68s1lc02',
#  '9ypQNsTsSQYlx72wxTLrHzzNoAJ2',
#  '.DS_Store',
#  'cfZUmZvsecYVKw5eSi4qIhfJVpI3',
#  '5ZDF98UQUxcVuS9VhaWxKlVnXvs1',
#  'tiKv850hJFTmpCAvfJOmOOqkeUs1',
#  'LqGeCxef4fN4IPanKEbWkO1fAwJ3',
#  'XUsJp0qysAPtu3vBI0UCiHRJhZ22',
#  'eZ9KEu3fmEgvxINqgcbkBXoEsv53',
#  'TRK6gUseEUS7dbF0soG80W1uLm53',
#  'iq8oYXczSjPuJoVS7DBpkGNMC2p1',
#  'O4BFgxvAgwbwRGZMkMBJRFnGBbd2',
#  'nMIOAh7qRFf3pqbchclOLKbPDOm1',
#  'Pr79fov0a5TW5KPo0XACvIqMtO72',
#  '60Ig4PmU9NMqKGDMR8Um0Tc2KXB3',
#  'CrlV0ddIqdbtxNnkIhtPS5dvoX42',
#  'KL32QXSSnLZlRRT2B6rQQQKgpx12',
# ...

# %%
path = os.getcwd()
file = 'vK2bLRNzllXNeyOMudnNSL5cfpG2'
new_path = os.path.join(path,file)
os.chdir(new_path)

# %%
os.listdir()
# Out:
# ['counting-normal.wav',
#  'metadata.json',
#  'vowel-o.wav',
#  'vowel-a.wav',
#  'vowel-e.wav',
#  'breathing-shallow.wav',
#  'counting-fast.wav',
#  'breathing-deep.wav',
#  'cough-heavy.wav',
#  'cough-shallow.wav']

# %%
import IPython.display as ipd

# %%
ipd.Audio('counting-normal.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load('counting-normal.wav',duration = 0.07)
ps = librosa.feature.melspectrogram(y = y, sr = sr)
ps.shape
# Out:
# /opt/anaconda3/envs/tf2/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1544
#   n_fft, y.shape[-1]
# (128, 4)

# %%
import librosa.display

# %%
librosa.display.specshow(ps, y_axis = 'mel', x_axis = 'time')

# %%
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load('counting-normal.wav')
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio('counting-normal.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt

# %%
x = librosa.stft(y)
Xdb = librosa.amplitude_to_db(abs(x))
plt.figure(figsize =(14,5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')

# %%
df = pd.read_csv('/Users/anushkadwivedi/Python_work/Coswara-Data/20200413/20200413.csv')

# %%
df.head()
# Out:
#                              id    l_c   a covid_status    iF ep     g  \
# 0  vK2bLRNzllXNeyOMudnNSL5cfpG2  India  24      healthy  True  y  male
# 1  bjA2KpSxneNskrLBeqi4bqoTDQl2  India  72      healthy  True  y  male
# 2  FSzobvJqOXf0rI6X05cHqOiU9Mu2  India  54      healthy  True  y  male
# 3  EqDWckxbsETyHUeBLQ8jLtxlhir2  India  31      healthy  True  y  male
# 4  FGRDO4IBbAejR0WHD5YbkXTCasg2  India  26      healthy  True  y  male
#
#            l_s   dT         l_l diabetes asthma smoker   ht fever
# 0    Karnataka  web         NaN      NaN    NaN    NaN  NaN   NaN
# 1  Maharashtra  web       Thane      NaN    NaN    NaN  NaN   NaN
# 2  Maharashtra  web  Thane West      NaN    NaN    NaN  NaN   NaN
# 3    Karnataka  web   Bangalore      NaN    NaN    NaN  NaN   NaN
# 4      Haryana  web     gurgaon      NaN    NaN    NaN  NaN   NaN

# %%
df.isna().sum()
# Out:
# id               0
# l_c              0
# a                0
# covid_status     0
# iF               0
# ep               0
# g                0
# l_s              0
# dT               0
# l_l              5
# diabetes        73
# asthma          72
# smoker          66
# ht              71
# fever           75
# dtype: int64

# %%
df.shape
# Out:
# (76, 15)

# %%
df.drop(['diabetes','asthma','smoker','ht','fever'],axis=1,inplace=True)

# %%
df
# Out:
#                               id    l_c   a                 covid_status  \
# 0   vK2bLRNzllXNeyOMudnNSL5cfpG2  India  24                      healthy
# 1   bjA2KpSxneNskrLBeqi4bqoTDQl2  India  72                      healthy
# 2   FSzobvJqOXf0rI6X05cHqOiU9Mu2  India  54                      healthy
# 3   EqDWckxbsETyHUeBLQ8jLtxlhir2  India  31                      healthy
# 4   FGRDO4IBbAejR0WHD5YbkXTCasg2  India  26                      healthy
# ..                           ...    ...  ..                          ...
# 71  0zexHIcM7tQDdnFiEj2Eb0v3g212  India  29                      healthy
# 72  uMry1yqi5sNoykw7ySJdITMv2yT2  India  28  resp_illness_not_identified
# 73  3VWhvtBFHKMgEKxlXzMYeg5NeBN2  India  37                      healthy
# 74  xyDgyXrDoyXu5CFqcNe20LRjYqg1  India  26      no_resp_illness_exposed
# 75  FLhjsgqrgQMKwNt5iEryxG5sDlW2  India  26                      healthy
#
#       iF ep       g            l_s   dT          l_l
# ...

# %%
df['breathing'] = df['id']+'/breathing-shallow.wav'

# %%
df
# Out:
#                               id    l_c   a                 covid_status  \
# 0   vK2bLRNzllXNeyOMudnNSL5cfpG2  India  24                      healthy
# 1   bjA2KpSxneNskrLBeqi4bqoTDQl2  India  72                      healthy
# 2   FSzobvJqOXf0rI6X05cHqOiU9Mu2  India  54                      healthy
# 3   EqDWckxbsETyHUeBLQ8jLtxlhir2  India  31                      healthy
# 4   FGRDO4IBbAejR0WHD5YbkXTCasg2  India  26                      healthy
# ..                           ...    ...  ..                          ...
# 71  0zexHIcM7tQDdnFiEj2Eb0v3g212  India  29                      healthy
# 72  uMry1yqi5sNoykw7ySJdITMv2yT2  India  28  resp_illness_not_identified
# 73  3VWhvtBFHKMgEKxlXzMYeg5NeBN2  India  37                      healthy
# 74  xyDgyXrDoyXu5CFqcNe20LRjYqg1  India  26      no_resp_illness_exposed
# 75  FLhjsgqrgQMKwNt5iEryxG5sDlW2  India  26                      healthy
#
#       iF ep       g            l_s   dT          l_l  \
# ...

# %%
df_new = df.copy()

# %%
df_new.head()
# Out:
#                              id    l_c   a covid_status    iF ep     g  \
# 0  vK2bLRNzllXNeyOMudnNSL5cfpG2  India  24      healthy  True  y  male
# 1  bjA2KpSxneNskrLBeqi4bqoTDQl2  India  72      healthy  True  y  male
# 2  FSzobvJqOXf0rI6X05cHqOiU9Mu2  India  54      healthy  True  y  male
# 3  EqDWckxbsETyHUeBLQ8jLtxlhir2  India  31      healthy  True  y  male
# 4  FGRDO4IBbAejR0WHD5YbkXTCasg2  India  26      healthy  True  y  male
#
#            l_s   dT         l_l  \
# 0    Karnataka  web         NaN
# 1  Maharashtra  web       Thane
# 2  Maharashtra  web  Thane West
# 3    Karnataka  web   Bangalore
# 4      Haryana  web     gurgaon
#
#                                            breathing
# 0  vK2bLRNzllXNeyOMudnNSL5cfpG2/breathing-shallow...
# 1  bjA2KpSxneNskrLBeqi4bqoTDQl2/breathing-shallow...
# 2  FSzobvJqOXf0rI6X05cHqOiU9Mu2/breathing-shallow...
# 3  EqDWckxbsETyHUeBLQ8jLtxlhir2/breathing-shallow...
# 4  FGRDO4IBbAejR0WHD5YbkXTCasg2/breathing-shallow...

# %%
df_new.drop(['id','l_c','a','iF','ep','g','l_s','dT','l_l'],axis = 1, inplace = True)

# %%
df_new.head()
# Out:
#   covid_status                                          breathing
# 0      healthy  vK2bLRNzllXNeyOMudnNSL5cfpG2/breathing-shallow...
# 1      healthy  bjA2KpSxneNskrLBeqi4bqoTDQl2/breathing-shallow...
# 2      healthy  FSzobvJqOXf0rI6X05cHqOiU9Mu2/breathing-shallow...
# 3      healthy  EqDWckxbsETyHUeBLQ8jLtxlhir2/breathing-shallow...
# 4      healthy  FGRDO4IBbAejR0WHD5YbkXTCasg2/breathing-shallow...

# %%
df_new.iloc[0,1]
# Out:
# 'vK2bLRNzllXNeyOMudnNSL5cfpG2/breathing-shallow.wav'

# %% [markdown]
# ### Extracting Features of single audio file

# %%
librosa_audio_data,librosa_sample_rate=librosa.load('breathing-shallow.wav')

# %%
print(librosa_audio_data)
# Out:
# [ 0.          0.          0.         ... -0.00025685 -0.00027067
#  -0.00029785]

# %%
### Lets plot the librosa audio data
import matplotlib.pyplot as plt
# Original audio with 1 channel 
plt.figure(figsize=(12, 4))
plt.plot(librosa_audio_data)

# %%
### Lets read with scipy
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read('breathing-shallow.wav')

# %%
wave_audio
# Out:
# array([ 0,  0,  0, ..., -9, -9, -9], dtype=int16)

# %%
plt.figure(figsize=(12,4))
plt.plot(wave_audio)

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio_data, sr=librosa_sample_rate, n_mfcc=40)
print(mfccs.shape)
# Out:
# (40, 258)

# %%
import soundfile as sf

# %%
DATA,SR = sf.read('vK2bLRNzllXNeyOMudnNSL5cfpG2/breathing-shallow.wav', channels=1, samplerate=48000,dtype=np.float32, subtype='PCM_32',format="RAW",endian='LITTLE')

# %%
mfccs_features = librosa.feature.mfcc(y=DATA, sr=SR, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

# %%
mfccs
# Out:
# array([[-7.6980969e+02, -6.9609369e+02, -6.3040234e+02, ...,
#         -5.7904889e+02, -6.4031720e+02, -6.9795844e+02],
#        [ 5.8639061e+01,  1.1346329e+02,  1.6023178e+02, ...,
#          1.7099623e+02,  1.5154074e+02,  1.1692093e+02],
#        [ 4.4957920e+01,  2.7145889e+01,  1.3390951e+01, ...,
#          9.1959343e+00,  2.3248302e+01,  3.7722458e+01],
#        ...,
#        [-5.6920462e+00, -1.3142145e+01, -1.1042156e+01, ...,
#          3.7089865e+00,  1.5902488e+00,  1.1058116e-01],
#        [-5.4161606e+00, -1.3151783e+01, -1.1819890e+01, ...,
#          5.2306008e+00,  3.4026489e+00,  4.8251301e-01],
#        [-4.9264860e+00, -5.9803734e+00, -2.6711893e+00, ...,
#         -2.3312364e+00, -2.8929968e+00, -3.6639147e+00]], dtype=float32)

# %% [markdown]
# ### Extracting features for every audio file

# %% [markdown]
# def features_extractor(file_name):
#     audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
#     mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
#     mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
#
#     return mfccs_scaled_features

# %%
def features_extractor(file_name):
    audio, sample_rate = sf.read(file_name, channels=1, samplerate=48000,dtype=np.float32, subtype='PCM_32',format="RAW",endian='LITTLE')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
from tqdm import tqdm
### Now we iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(df_new.iterrows()):
    file_name = row['breathing']
    final_class_labels=row["covid_status"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 20it [00:00, 65.25it/s]/opt/anaconda3/envs/tf2/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=11
#   n_fft, y.shape[-1]
# 76it [00:01, 73.57it/s]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['breathing','covid_status'])
extracted_features_df.head()
# Out:
#                                            breathing covid_status
# 0  [-395.20718, 27.001255, 6.606872, -1.5997101, ...      healthy
# 1  [-704.9501, 46.658813, -2.8637643, -1.4860778,...      healthy
# 2  [-500.36633, 22.275047, -31.536402, 26.423504,...      healthy
# 3  [-586.481, 16.221504, -14.875951, -5.2539067, ...      healthy
# 4  [-265.07004, -0.7351184, -29.448828, 0.9499488...      healthy

# %%
x = np.array(extracted_features_df['breathing'].tolist())
y = np.array(extracted_features_df['covid_status'].tolist())

# %%
x.shape
# Out:
# (76, 40)

# %%
y = np.array(pd.get_dummies(y))

# %%
y.shape
# Out:
# (76, 3)

# %%
extracted_features_df['covid_status'].value_counts()
# Out:
# healthy                        66
# resp_illness_not_identified     5
# no_resp_illness_exposed         5
# Name: covid_status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[-5.4153595e+02,  2.4726164e+01, -9.9216824e+00, ...,
#          1.0226662e+00,  1.8614016e+00,  1.4174470e+00],
#        [-5.1749091e+02,  2.4728168e+01,  1.1294637e+01, ...,
#          7.1468234e-01, -1.3436234e+00,  1.4327103e+00],
#        [-5.8313080e+02,  5.3988258e+01, -7.3213058e+01, ...,
#          2.4653050e-01,  2.7869549e+00,  2.5438855e+00],
#        ...,
#        [-4.1416959e+02,  2.3688873e+01,  9.7174187e+00, ...,
#         -5.9891051e-01,  1.3383842e-02, -6.6846406e-01],
#        [-4.6126523e+02,  1.0780799e+01, -2.0524233e+01, ...,
#          1.0741283e+00,  6.1297333e-01,  3.7739851e+00],
#        [-5.0683859e+02, -1.7281628e+01, -7.6059517e+01, ...,
#          7.4099845e-01,  5.8515325e+00,  2.2034380e+00]], dtype=float32)

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
num_labels=y.shape[1]

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))

###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 100)               4100
# _________________________________________________________________
# activation (Activation)      (None, 100)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               20200
# _________________________________________________________________
# activation_1 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# ...

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
#from tensorflow.keras.callbacks

num_epochs = 100
num_batch_size = 32

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), verbose=1)
# Out:
# Train on 60 samples, validate on 16 samples
# Epoch 1/100
# 60/60 [==============================] - 0s 1ms/sample - loss: 32.3871 - accuracy: 0.6667 - val_loss: 17.6905 - val_accuracy: 0.8125
# Epoch 2/100
# 60/60 [==============================] - 0s 797us/sample - loss: 30.5616 - accuracy: 0.6833 - val_loss: 20.3378 - val_accuracy: 0.8125
# Epoch 3/100
# 60/60 [==============================] - 0s 665us/sample - loss: 23.8802 - accuracy: 0.7667 - val_loss: 22.1270 - val_accuracy: 0.8125
# Epoch 4/100
# 60/60 [==============================] - 0s 684us/sample - loss: 32.9205 - accuracy: 0.8667 - val_loss: 21.7690 - val_accuracy: 0.8125
# Epoch 5/100
# 60/60 [==============================] - 0s 675us/sample - loss: 26.4392 - accuracy: 0.8167 - val_loss: 20.9535 - val_accuracy: 0.8125
# Epoch 6/100
# 60/60 [==============================] - 0s 649us/sample - loss: 19.1347 - accuracy: 0.8000 - val_loss: 19.8016 - val_accuracy: 0.8125
# Epoch 7/100
# ...

# %%
test_accuracy=model.evaluate(x_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8125

# %%
train_accuracy=model.evaluate(x_train,y_train,verbose=0)
print(train_accuracy[1])
# Out:
# 0.8833333
